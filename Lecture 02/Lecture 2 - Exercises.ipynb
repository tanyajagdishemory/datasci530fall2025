# %% [markdown]
# # Lecture 2 Exercises

# %% [markdown]
# ## Short Questions
#
# <font size = "5">
#
# 1. How do you check whether an element is part of a list?
# 2. How do you reference a global variable in ```.query()```?

# %%
# Write your answers here as comments:

# 1. using 'in' operator
# 2. using '@' prefix

# %% [markdown]
# ## Long Questions

# %% [markdown]
# <font size = "5">
#
# Import the pandas and matplotlib packages

# %%
# Write your own code

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <font size = "5">
#
# (a) Checking a string condition
#
# <font size = "3">
#
# - Define a variable "fruit" with the value "apple"
# - Define a list
#
# list_fruits = ["banana","orange","apple"]
# - Write an expression to test whether "fruit" is contained in "list_fruits"
#
# Hint: Use the "in" command. The final output should be True/False.
#
# To get full points run all of the above commands

# %%
# Write your own code

variable = "apple"
list_fruits = ["banana", "orange", "apple"]

print(variable in list_fruits)
# Out:
# True

# %% [markdown]
# <font size = "5">
#
# (b) Classifying a variable
#
# <font size = "3">
#
# - Define a new variable "year" an assign the value "2008"
# - Write an if/else statement that does the following
#     - print("Year 2000 or earlier") if the year is less than or equal to  2000.
#     - print("Between 2001 and 2005") if the year is between 2001 and 2005.
#     - print("Year 2006 or later") if the year is after 2005.
#
# To get full points you must do all of the above instructions

# %%
# Write your own code

year = 2008


if year <= 2000:
    print("Year 2000 or earlier")
elif (year > 2000) & (year < 2005):
    print("Between 2001 and 2005")
else:
    print("Year 2006 or later")
# Out:
# Year 2006 or later

# %% [markdown]
# <font size = "5">
#
# (c) Split a dataset into subsets
#
# <font size = "3">
#
# - Import the "features.csv" file as a pandas dataframe called "data"
# - Create ``` list_status = [0,1]```
# - Create ``` list_prob = [0.5, 0.5]```
# - Create a new variable $n = 1000$ with the number of rows of the dataset
# - Use
# ```python
#     np.random.choice(list_status,
#                      size = n,
#                      p = list_prob)
# ```
# $\qquad$ to create a new column called "status" <br>
# $\qquad$ which randomly assigns each row to "0" or "1" <br>
# $\qquad$ with equal probability
# - Use .query() to subset all observations with status == 0.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with status == 1.<br>
# store it in a new dataset called "data1"

# %%
# Write your own code

data = pd.read_csv("data_raw/features.csv")

list_status = [0,1]
list_prob = [0.5, 0.5]
n = len(data)

random_status = np.random.choice(list_status,
                                  size = n,
                                  p = list_prob)

data["status"] = random_status

data0 = data.query("status == 0")
data1 = data.query("status == 1")

# %% [markdown]
# <font size = "5">
#
# For questions (d) through (f) mport the dataset <br>
#  "data_raw/fifa23_players_basic.csv"
#
# <font size = "3">
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting

# %%
# Write your own code

soccer_dataset = pd.read_csv("data_raw/fifa23_players_basic.csv")

# %% [markdown]
# <font size = "5">
#
# (d) Create a new dataset subsetting the <br>
# players whose age is less than 20

# %%
# Write your own code

less_than_20 = soccer_dataset.query("Age < 20")

# %% [markdown]
# <font size = "5">
#
# (e) Use queries + global variables
#
# <font size = "3">
#
# - Compute the mean of the column "Value(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Value(in Euro)`    ``` inside .query()

# %%
# Write your own code

mean_value = np.mean(soccer_dataset["Value(in Euro)"])

soccer_dataset.query("`Value(in Euro)` > @mean_value")
# Out:
#             Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0           L. Messi        Lionel Messi       91         91        54000000
# 1         K. Benzema       Karim Benzema       91         91        64000000
# 2     R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3       K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4          K. Mbappé       Kylian Mbappé       91         95       190500000
# ...              ...                 ...      ...        ...             ...
# 7066       F. Rieder       Fabian Rieder       68         83         2900000
# 7071     J. Bakayoko      Johan Bakayoko       68         85         3100000
# 7090        M. Arezo        Matías Arezo       68         81         2900000
# 7096       Y. Kallon        Yayah Kallon       68         82         3000000
# 7168        M. Soulé        Matías Soulé       68         85         3100000
#
#      Positions Played Best Position   Nationality  \
# 0                  RW           CAM     Argentina
# 1               CF,ST            CF        France
# 2                  ST            ST        Poland
# 3              CM,CAM            CM       Belgium
# 4               ST,LW            ST        France
# ...               ...           ...           ...
# 7066           CAM,CM           CAM   Switzerland
# 7071               RW            LM       Belgium
# 7090           ST,CAM            ST       Uruguay
# 7096         RM,RW,CF            ST  Sierra Leone
# 7168               RW            LM     Argentina
#
#                                             Image Link  Age  ...  \
# 0     https://cdn.sofifa.net/players/158/023/23_60.png   35  ...
# 1     https://cdn.sofifa.net/players/165/153/23_60.png   34  ...
# 2     https://cdn.sofifa.net/players/188/545/23_60.png   33  ...
# 3     https://cdn.sofifa.net/players/192/985/23_60.png   31  ...
# 4     https://cdn.sofifa.net/players/231/747/23_60.png   23  ...
# ...                                                ...  ...  ...
# 7066  https://cdn.sofifa.net/players/259/306/23_60.png   20  ...
# 7071  https://cdn.sofifa.net/players/265/450/23_60.png   19  ...
# 7090  https://cdn.sofifa.net/players/254/653/23_60.png   19  ...
# 7096  https://cdn.sofifa.net/players/262/333/23_60.png   21  ...
# 7168  https://cdn.sofifa.net/players/265/695/23_60.png   19  ...
#
#       Preferred Foot  Weak Foot Rating  Skill Moves  International Reputation  \
# 0               Left                 4            4                         5
# 1              Right                 4            4                         4
# 2              Right                 4            4                         5
# 3              Right                 5            4                         4
# 4              Right                 4            5                         4
# ...              ...               ...          ...                       ...
# 7066            Left                 3            2                         1
# 7071            Left                 3            3                         1
# 7090           Right                 3            4                         1
# 7096            Left                 2            3                         1
# 7168            Left                 4            4                         1
#
#      National Team Name             National Team Image Link  \
# 0             Argentina  https://cdn.sofifa.net/flags/ar.png
# 1                France  https://cdn.sofifa.net/flags/fr.png
# 2                Poland  https://cdn.sofifa.net/flags/pl.png
# 3               Belgium  https://cdn.sofifa.net/flags/be.png
# 4                France  https://cdn.sofifa.net/flags/fr.png
# ...                 ...                                  ...
# 7066                  -  https://cdn.sofifa.net/flags/ch.png
# 7071                  -  https://cdn.sofifa.net/flags/be.png
# 7090                  -  https://cdn.sofifa.net/flags/uy.png
# 7096                  -                                    -
# 7168                  -  https://cdn.sofifa.net/flags/ar.png
#
#       National Team Position National Team Jersey Number Attacking Work Rate  \
# 0                         RW                          10                 Low
# 1                         ST                          19              Medium
# 2                         ST                           9                High
# 3                         RF                           7                High
# 4                         ST                          10                High
# ...                      ...                         ...                 ...
# 7066                       -                           -                High
# 7071                       -                           -                High
# 7090                       -                           -                High
# 7096                       -                           -                High
# 7168                       -                           -                High
#
#      Defensive Work Rate
# 0                    Low
# 1                 Medium
# 2                 Medium
# 3                   High
# 4                    Low
# ...                  ...
# 7066              Medium
# 7071              Medium
# 7090              Medium
# 7096                 Low
# 7168              Medium
#
# [3216 rows x 32 columns]

# %% [markdown]
# <font size = "5">
#
# (f) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Use ".sort_values()" to order the "Age" column <br>
# from youngest to oldest
# - Get a subset with the 5 youngest players

# %%
# Write your own code

sorted_age = soccer_dataset.sort_values("Age", ascending= True)

display(sorted_age.iloc[:5, :])
# Out:
#           Known As         Full Name  Overall  Potential  Value(in Euro)  \
# 18425    M. Moraru      Matei Moraru       50         72          150000
# 18232    B. Faraas   Benjamin Faraas       51         76          180000
# 18284   D. Lipsiuc    Darius Lipsiuc       51         65          130000
# 18014    J. Ardila       José Ardila       53         73          250000
# 16880  M. Kowalski  Mateusz Kowalski       56         75          350000
#
#       Positions Played Best Position          Nationality  \
# 18425            CM,RW           CAM              Romania
# 18232               CM           CAM               Norway
# 18284              CAM           CAM  Republic of Ireland
# 18014               CM           CAM            Venezuela
# 16880               ST            ST               Poland
#
#                                              Image Link  Age  ...  \
# 18425  https://cdn.sofifa.net/players/271/182/23_60.png   16  ...
# 18232  https://cdn.sofifa.net/players/271/433/23_60.png   16  ...
# 18284  https://cdn.sofifa.net/players/268/281/23_60.png   16  ...
# 18014  https://cdn.sofifa.net/players/268/892/23_60.png   16  ...
# 16880  https://cdn.sofifa.net/players/270/716/23_60.png   16  ...
#
#        Preferred Foot  Weak Foot Rating  Skill Moves  \
# 18425           Right                 2            2
# 18232           Right                 2            2
# 18284           Right                 3            2
# 18014           Right                 3            2
# 16880           Right                 2            2
#
#        International Reputation National Team Name  \
# 18425                         1                  -
# 18232                         1                  -
# 18284                         1                  -
# 18014                         1                  -
# 16880                         1                  -
#
#                   National Team Image Link  National Team Position  \
# 18425  https://cdn.sofifa.net/flags/ro.png                       -
# 18232  https://cdn.sofifa.net/flags/no.png                       -
# 18284                                    -                       -
# 18014  https://cdn.sofifa.net/flags/ve.png                       -
# 16880  https://cdn.sofifa.net/flags/pl.png                       -
#
#       National Team Jersey Number Attacking Work Rate Defensive Work Rate
# 18425                           -              Medium              Medium
# 18232                           -              Medium              Medium
# 18284                           -              Medium              Medium
# 18014                           -              Medium              Medium
# 16880                           -                High              Medium
#
# [5 rows x 32 columns]

# %% [markdown]
# <font size = "5">
# For questions (h)-(i), read "data_raw/wdi_2020.csv" <br>
# This is a dataset of countries from <br>
# the World Development Indicators

# %% [markdown]
# <font size = "5">
#
# (g) Extract sorted elements from a dataset
#
# <font size = "3">
#
# - Sort by "prop_urbanpopulation" in descending order
# - Subset the 5 countries with the highest urban population

# %%
# Write your own code

worldbank_indicators = pd.read_csv("data_raw/wdi_2020.csv")

sorted_popl = worldbank_indicators.sort_values("prop_urbanpopulation", ascending = False)

display(sorted_popl.iloc[:5, :])
# Out:
#      year yearcode                countryname countrycode  \
# 213  2020   YR2020  Sint Maarten (Dutch part)         SXM
# 24   2020   YR2020                    Bermuda         BMU
# 103  2020   YR2020       Hong Kong SAR, China         HKG
# 90   2020   YR2020                  Gibraltar         GIB
# 212  2020   YR2020                  Singapore         SGP
#
#      prop_urbanpopulation
# 213                 100.0
# 24                  100.0
# 103                 100.0
# 90                  100.0
# 212                 100.0

# %% [markdown]
# <font size = "5">
#
# (h) Subset elements with query
#
# <font size = "3">
#
# - Compute the median of "prop_urbanpopulation"
# - Use ".query()" to subset countries with <br>
#  "prop_urbanpopulation" above the median

# %%
# Write your own code

median = worldbank_indicators["prop_urbanpopulation"].median()
display(median)

above_median = worldbank_indicators.query("prop_urbanpopulation > @median")
# Out:
# 60.69872843

# %% [markdown]
# <font size = "5">
#
# (i) Plot by category
#
# <font size = "3">
#
# - Read "data_raw/wdi_urban.csv"<br>
# This contains data from 1980 and 2020
#
# - Create a list with the unique values of "year"
# - Create a plot with a ...
#     - Histogram of "prop_urbanpopulation" <br>
#     for each year
#     - Set the histogram option ``` alpha = 0.5 ``` for transparency
#     - All the histograms should be overlapping
#     - Create a legend with the list of years
#     - Label the axes and the title
#
# What do we learn from the graph?
#
# HINT: See the example at the end of Lecture 10

# %%
# Write your own code

wdi_urban = pd.read_csv("data_raw/wdi_urban.csv")

list_unique_year = pd.unique(wdi_urban["year"])
print(list_unique_year)

for years in list_unique_year:
    df = wdi_urban.query("year == @years")
    plt.hist(df["prop_urbanpopulation"], alpha = 0.5, label = str(years))

plt.xlabel("Urban population (% of total)")
plt.ylabel("Number of countries")
plt.legend(title = "Year")
plt.tight_layout()
plt.show


# this shows us that urban population in countries has increased over time
# Out:
# [1980 2020]
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Review of last lecture

# %% [markdown]
# <font size = "5">
#
# (k) Composite operations on arrays
#
# <font size = "3">
#
# - Define $r = 0.04$
# - Define two arrays $A$ and $T$ using "np.array()", assigning the following values
#
# $ a = \begin{pmatrix} a_0 \\ a_1 \\ a_2 \end{pmatrix} =  \begin{pmatrix} 20 \\ 30 \\ 15 \end{pmatrix},
# \qquad  t = \begin{pmatrix} t_0 \\ t_1 \\ t_2 \end{pmatrix} = \begin{pmatrix} 0 \\ 1 \\ 2 \end{pmatrix} $
#
# - Use element-by-element vector operations to compute a new array $M$ of length 3:
#
# $ M = \begin{pmatrix} a_1 / (1+r)^{t_0}  \\ a_2 / (1+r)^{t_1} \\ a_3 / (1+r)^{t_2} \end{pmatrix} $
#
# - Compute the sum of the values of $M$ using "M.sum()"
#
# Note: I am using subscripts to denote the individual elements of $a$ and $t$.
# - In the code just enter the values of $a$ and $t$.
# - To get full points you must do all of the above tasks

# %%
# Write your own code

r = 0.04

a = np.array([20, 30, 15])
t = np.array([0, 1, 2])

M = a/(1+r)**t

print(M)
print(M.sum())

#osndismd
# Out:
# [20.         28.84615385 13.8683432 ]
# 62.71449704142012
